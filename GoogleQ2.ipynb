# %%
import numpy as np
import numexpr as ne
import math
import datetime

def isPrime2(n):
    a=5
    v=2
    if n % 2 == 0 or n % 3 == 0:
        return False
    if n == 2 or n == 3:
        return True
    while a * a <= n:
        if n % a == 0:
            return False
        a=a+v
        v=6-v
    return True


def isPrime(n):
    return all(n%i for i in xrange(2, int(math.sqrt(n))+1))

def primeListCheck(valList):
    for i in valList:
        PrimeCheck = isPrime2(i)
        if PrimeCheck:
            print i
            return PrimeCheck
    return PrimeCheck

def getDivisor(NUM):
    for i in range(2,int(math.sqrt(NUM))+1):
        if NUM%i==0:
            return i

def baseN(candidate, base, DIG):
    candidateList = np.array([int(i) for i in candidate])
    powN = [base**x for x in (range(DIG))][::-1]
    return sum(candidateList*powN)

def isPrime(n):
    return all(n%i for i in xrange(2, n))

def isJamCoin(candidate):
    DIG = len(candidate)
    coinVal = [baseN(candidate,i,DIG) for i in range(2,11)]
    primeCheck = primeListCheck(coinVal)
    if primeCheck == False:
        return (True,candidate, coinVal)
    return (False,False)

def getCandidates(DIG):
    BINARY=np.array([2**i for i in range(DIG)])[::-1]

    MIN=sum(BINARY*np.array([int(imin) for imin in "1"+(DIG-1)*"0"]))
    MAX=sum(BINARY*np.array([int(imax) for imax in DIG*"1"]))
    #print BINARY
    #print MAX

    NUMLIST = np.arange(MIN, MAX+1)
    BINLIST = np.array(["{0:b}".format(i) for i in NUMLIST])
    BB = [[i[-1]=='1'] for i in BINLIST]
    BBI = np.array([i[0] for i in BB])

    CANDIDATES = BINLIST[BBI]
    return CANDIDATES

def getFinalCoins(DIG,NUMTOGET):
    FINAL=[]
    GC = getCandidates(DIG)
    GCX = np.random.choice(GC,GC.shape[0],replace=False)
    #GCX=GC
    for i in GCX:
        J = isJamCoin(i)
        if J[0]==True:
            FINAL.append(J)
            print str(datetime.datetime.now()),"  Found Value: ",str(len(FINAL)), " => ", str(J)
            if len(FINAL)==NUMTOGET:
                return FINAL

def final(DIG, NUMTOGET):
    Z = getFinalCoins(DIG, NUMTOGET)
    for (i,j,k) in Z:
        RESULT = [j,[getDivisor(v) for v in k]]
        print str(RESULT[0]) + " " + " ".join(str(item) for item in RESULT[1])

def finalSave(inputFile):
    fp = open(inputFile)
    saveFile = "result_"+inputFile
    saveFile2 = "result_2"+inputFile
    
    tg = open(saveFile,'w')
    
    tg.write("Case #1:")
    tg.write("\n")
   
    for (ix, line) in enumerate(fp):
        if ix==0:
            pass
        else:
            val = line.split(" ")
            DIG=int(val[0])
            NUMTOGET=int(val[1])
    
    Z = getFinalCoins(DIG, NUMTOGET)
    for (i,j,k) in Z:
        tg2 = open(saveFile2,'a')
        RESULT = [j,[getDivisor(v) for v in k]]
        RESWRITE = str(RESULT[0]) + " " + " ".join(str(item) for item in RESULT[1])
        tg.write(RESWRITE)
        tg.write("\n")
        tg2.write(RESWRITE)
        tg2.write("\n")
        tg2.close()
    fp.close()
    tg.close()

# %%
#finalSave("t.txt")

# %%
DIG=32
BINARY=np.array([2**i for i in range(DIG)])[::-1]
MIN=sum(BINARY*np.array([int(imin) for imin in "1"+(DIG-1)*"0"]))
MAX=sum(BINARY*np.array([int(imax) for imax in DIG*"1"]))

# %%
#NUMLIST = np.arange(MIN, MAX+1)
#BINLIST = np.array(["{0:b}".format(i) for i in NUMLIST])

# %%
MIN
# Out:
# 2147483648

# %%
MAX
# Out:
# 4294967295

# %%
MAX-MIN
# Out:
# 2147483647

# %%
ZZ = MIN+range(2)
np.array(["{0:b}".format(i) for i in ZZ])
# Out:
# array(['10000000000000000000000000000000',
#        '10000000000000000000000000000001'],
#       dtype='|S32')

# %%
#RERUN this for Large Question Set, uses early stopping for Prime Check

import numpy as np
import numexpr as ne
import math
import datetime


def isPrimeLargeSetQ3(n):
    a=5
    v=2
    if n % 2 == 0 or n % 3 == 0:
        return False
    if n == 2 or n == 3:
        return True
    c = 0
    while (a * a <= n) and (c < 1000):
        c += 1
        #print c
        if n % a == 0:
            #print c
            return False
        a=a+v
        v=6-v
    return True


def primeListCheck(valList):
    for i in valList:
        PrimeCheck = isPrimeLargeSetQ3(i)
        if PrimeCheck:
            print i
            return PrimeCheck
    return PrimeCheck

def getDivisor(NUM):
    for i in range(2,int(math.sqrt(NUM))+1):
        if NUM%i==0:
            return i

def baseN(candidate, base, DIG):
    candidateList = np.array([int(i) for i in candidate])
    powN = [base**x for x in (range(DIG))][::-1]
    return sum(candidateList*powN)

def isPrime(n):
    return all(n%i for i in xrange(2, n))

def isJamCoin(candidate):
    DIG = len(candidate)
    coinVal = [baseN(candidate,i,DIG) for i in range(2,11)]
    primeCheck = primeListCheck(coinVal)
    if primeCheck == False:
        return (True,candidate, coinVal)
    return (False,False)

def getCandidates(DIG):
    BINARY=np.array([2**i for i in range(DIG)])[::-1]

    MIN=sum(BINARY*np.array([int(imin) for imin in "1"+(DIG-1)*"0"]))
    MAX=sum(BINARY*np.array([int(imax) for imax in DIG*"1"]))
    #print BINARY
    #print MAX

    NUMLIST = np.arange(MIN, MAX+1)
    BINLIST = np.array(["{0:b}".format(i) for i in NUMLIST])
    BB = [[i[-1]=='1'] for i in BINLIST]
    BBI = np.array([i[0] for i in BB])

    CANDIDATES = BINLIST[BBI]
    return CANDIDATES

def getFinalCoins(DIG,NUMTOGET):
    FINAL=[]
    GC = getCandidates(DIG)
    GCX = np.random.choice(GC,GC.shape[0],replace=False)
    #GCX=GC
    for i in GCX:
        J = isJamCoin(i)
        if J[0]==True:
            FINAL.append(J)
            print str(datetime.datetime.now()),"  Found Value: ",str(len(FINAL)), " => ", str(J)
            if len(FINAL)==NUMTOGET:
                return FINAL

def final(DIG, NUMTOGET):
    Z = getFinalCoins(DIG, NUMTOGET)
    for (i,j,k) in Z:
        RESULT = [j,[getDivisor(v) for v in k]]
        print str(RESULT[0]) + " " + " ".join(str(item) for item in RESULT[1])

def finalSave(inputFile):
    fp = open(inputFile)
    saveFile = "result_"+inputFile
    saveFile2 = "result_2"+inputFile
    
    tg = open(saveFile,'w')
    
    tg.write("Case #1:")
    tg.write("\n")
   
    for (ix, line) in enumerate(fp):
        if ix==0:
            pass
        else:
            val = line.split(" ")
            DIG=int(val[0])
            NUMTOGET=int(val[1])
    
    Z = getFinalCoins(DIG, NUMTOGET)
    for (i,j,k) in Z:
        tg2 = open(saveFile2,'a')
        RESULT = [j,[getDivisor(v) for v in k]]
        RESWRITE = str(RESULT[0]) + " " + " ".join(str(item) for item in RESULT[1])
        tg.write(RESWRITE)
        tg.write("\n")
        tg2.write(RESWRITE)
        tg2.write("\n")
        tg2.close()
    fp.close()
    tg.close()

# %%
final(24,3)
# Out:
# Traceback (most recent call last):
#   File "/Users/xbsd/anaconda/lib/python2.7/site-packages/IPython/core/ultratb.py", line 776, in structured_traceback
#     records = _fixed_getinnerframes(etb, context, tb_offset)
#   File "/Users/xbsd/anaconda/lib/python2.7/site-packages/IPython/core/ultratb.py", line 230, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/xbsd/anaconda/lib/python2.7/site-packages/IPython/core/ultratb.py", line 259, in _fixed_getinnerframes
#     records  = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/xbsd/anaconda/lib/python2.7/inspect.py", line 1044, in getinnerframes
#     framelist.append((tb.tb_frame,) + getframeinfo(tb, context))
#   File "/Users/xbsd/anaconda/lib/python2.7/inspect.py", line 1004, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/xbsd/anaconda/lib/python2.7/inspect.py", line 454, in getsourcefile
#     if hasattr(getmodule(object, filename), '__loader__'):
#   File "/Users/xbsd/anaconda/lib/python2.7/inspect.py", line 500, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/Users/xbsd/anaconda/lib/python2.7/posixpath.py", line 382, in realpath
#     path, ok = _joinrealpath('', filename, {})
#   File "/Users/xbsd/anaconda/lib/python2.7/posixpath.py", line 393, in _joinrealpath
#     name, _, rest = rest.partition(sep)
# KeyboardInterrupt
# ERROR: Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
#
# Unfortunately, your original traceback can not be constructed.
# KeyboardInterrupt:
